# %% [markdown]
# # $\nu$-SQuIDS Demo: Welcome!

# %%
get_ipython().magic(u'matplotlib inline')
import matplotlib as mpl
import nuSQUIDSpy as nsq
import nuSQUIDSTools
import numpy as np
mpl.rc('font', family='serif', size=20)

# %% [markdown]
# Welcome to the $\nu$-SQuIDS demo. In
# this notebook we will demostrate some of the functionalities of the $\nu$-SQuIDS' python bindings. All of the calculations performed here can also be done in the C++ interface. Enjoy :)! Carlos & Jordi.

# %% [markdown]
# ## The Basics: simple example

# %% [markdown]
# #### Basic definitions

# %% [markdown]
# To start, like in the C++ case, we need to create a $\nu$-SQuIDS object. To begin this demonstration we will create a simple single energy three flavor neutrino oscillation calculator. Thus we just need to specify the number of neutrinos (3) and if we are dealing with neutrinos or antineutrinos.

# %%
nuSQ = nsq.nuSQUIDS(3,"neutrino")

# %% [markdown]
# As in the C++ $\nu$-SQuIDS interface one can propagate the neutrinos in various environments (see the documentation for further details), and the user can create and include their own environments. To start a simple case, lets consider oscillactions in <strong> Vacuum </strong>

# %%
nuSQ.Set_Body(nsq.Vacuum())

# %% [markdown]
# Since we have specify that we are considering vacuum propagation, we must construct - as in the C++ interface - a *trayectory* inside that object. This can be done using the `Track` property of the given `Body`. Each `Body` will have its on `Track` subclass and its constructors. We can set and construct a <strong>vacuum trayectory</strong> in the following way:

# %%
nuSQ.Set_Track(nsq.Vacuum.Track(0.,100.0*nuSQ.units.km))

# %% [markdown]
# Next we have to set the <strong>neutrino energy</strong>, which can be done as follows

# %%
nuSQ.Set_E(1.0*nuSQ.units.GeV)

# %% [markdown]
# Now we have to tell $\nu$-SQuIDS what is the **initial neutrino state** and if such state is given in the **flavor or mass basis**. We can do this using the `Set_initial_state` function and providing it with a *list* and a *string*. If the string is *flavor* then list must contain [$\phi_e$,$\phi_\mu$,$\phi_\tau$], similarly if the string is *mass* it the list must specify $\phi_i$. Lets set the initial state to $\nu_\mu$.

# %%
nuSQ.Set_initial_state(np.array([0,1,0]),"flavor")

# %% [markdown]
# Finally we can tell $\nu$-SQuIDS to perform the calculation. In case one (or all) of the above parameters is not set $\nu$-SQuIDS will throw an exception and tell you to fix it, but if you have defined everything then it will evolve the given state.

# %%
# %time
nuSQ.EvolveState()
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs

# %% [markdown]
# After this runs $\nu$-SQuIDS has evolved the state and store it in memory. Now there are lots of things you can ask $\nu$-SQuIDS to do. What is the flavor composition now?

# %%
[nuSQ.EvalFlavor(i) for i in range(3)]
# Out:
# [0.005102281344228465, 0.9081523153175108, 0.08674540333826056]

# %% [markdown]
# #### Writing and Reading the state

# %% [markdown]
# $\nu$-SQuIDS knows everything about the neutrino state at the current moment, it also knows what we did with it so far, where it went, what mixing parameters were used, etc. It would be comvinient to store this information. One way of doing this is to **save the $\nu$-SQuIDS status**, we can do this in the following way

# %%
nuSQ.WriteStateHDF5("current_state.hdf5")

# %% [markdown]
# Everything that is in the $\nu$-SQuIDS object is now in that file. We can use that file to create a new $\nu$-SQuIDS object and do another calculation, we can stop the calculation midway and use it to restart, we can explore that file with other analysis tools, etc. In particular, the `ReadStateHDF5` will return us to the given configuration.

# %%
nuSQ.ReadStateHDF5("current_state.hdf5")

# %% [markdown]
# #### Simple Plot

# %% [markdown]
# Lets use the current tool to try to calculate $P(\nu_\mu \to \nu_e)$ as a function of energy. We can do the following

# %%
energy_values = np.linspace(1,10,40)
nu_mu_to_nu_e = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(0))

# %%
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')

# %% [markdown]
# #### Changing the oscillation parameters

# %% [markdown]
# This is a nice plot. But we do not see an *oscillation* like curve. The reason for this is that the oscillation parameters do not produce an oscillation pattern in this $L/E$ scale. **$\nu$-SQuIDs has some predefined oscillation mixing angles ($\theta_{ij}$) and mass splittings ($\Delta m^2_{ij}$)**, which we have taken from the most recents fits. Perhaps you want to change this parameter to investigate what happens, this can be done easily using the `Set` function.

# %%
nuSQ.Set("dm21sq",7.0e-5) # sets dm^2_{21} in eV^2.

# %% [markdown]
# We can then, again, do a plot with this simple script

# %%
energy_values = np.linspace(1,10,60)
nu_mu_to_nu_e = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(0))

# %%
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')

# %% [markdown]
# We can also try to modify the mixing angles (see how to do this in detail in the documentation), for example

# %%
nuSQ.Set("th12",1.2) # sets \theta_{12} in radians.
nuSQ.Set("th13",0.3) # sets \theta_{23}} in radians.
nuSQ.Set("th23",0.4) # sets \theta_{23}} in radians.

# %%
energy_values = np.linspace(1,10,60)
nu_mu_to_nu_e = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(0))

figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')

# %% [markdown]
# #### Changing where the neutrino propagation takes place

# %% [markdown]
# As in the C++ implementation we can change the `Body` by means of the `Set_Body` function and in similar way we can change the `Track`. Lets do an atmospheric oscillation example =).

# %%
nuSQ = nsq.nuSQUIDS(3,"neutrino")
nuSQ.Set_Body(nsq.EarthAtm())
nuSQ.Set_Track(nsq.EarthAtm.Track(np.arccos(-1)))
nuSQ.Set("rel_error", 1.0e-15)
nuSQ.Set("abs_error", 1.0e-15)

nuSQ.Set("th12",0.563942)
nuSQ.Set("th13",0.154085)
nuSQ.Set("th23",0.785398)
nuSQ.Set("dm21sq",7.65e-05)
nuSQ.Set("dm31sq",0.00247)
nuSQ.Set("delta1",0.0)

# %%
energy_values = np.linspace(1,100,120)
energy_values = np.logspace(0,2,120)
nu_mu_to_nu_e = []
nu_mu_to_nu_mu = []
nu_mu_to_nu_tau = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(0))
    nu_mu_to_nu_mu.append(nuSQ.EvalFlavor(1))
    nu_mu_to_nu_tau.append(nuSQ.EvalFlavor(2))

figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"Oscillation Probability")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'red', label = r"$\nu_e$")
plot(energy_values,nu_mu_to_nu_mu, lw = 2, color = 'blue',label = r"$\nu_\mu$")
plot(energy_values,nu_mu_to_nu_tau, lw = 2, color = 'green', label = r"$\nu_\tau$")
legend(fancybox = True, fontsize = 15, loc = 7)
semilogx()
ylim(0,1)
savefig("earth_oscillation.pdf")

# %%
nuSQ.Set_Body(nsq.Earth())
nuSQ.Set_Track(nsq.Earth.Track(0.0,750.0*nuSQ.units.km,750.0*nuSQ.units.km))

# %%
nuSQ.Set("rel_error", 1.0e-15)
nuSQ.Set("abs_error", 1.0e-17)

# %%
energy_values = np.linspace(1,10,70)
nu_mu_to_nu_e = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(1))

figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')

# %%
nuSQ = nsq.nuSQUIDS(3,"neutrino")
nuSQ.Set_Body(nsq.ConstantDensity(13.0,0.5))
nuSQ.Set_Track(nsq.ConstantDensity.Track(0.0,1000.0*nuSQ.units.km))

# %%
nuSQ.Set("th12",0.569595)
nuSQ.Set("th13",0.201357)
nuSQ.Set("th23",0.785398)
nuSQ.Set("dm21sq",7.9e-5)
nuSQ.Set("dm31sq",2.5e-3)
nuSQ.Set("delta1",0.0)

# %%
energy_values = np.logspace(-2,2,500)
nu_mu_to_nu_e = []
for Enu in energy_values:
    nuSQ.Set_E(Enu*nuSQ.units.GeV)
    nuSQ.Set_initial_state([0,1,0],"flavor")
    nuSQ.EvolveState()
    nu_mu_to_nu_e.append(nuSQ.EvalFlavor(0))

figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')
semilogx()
savefig("nu_mu_nue_single_energy.eps")

# %%
figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
plot(energy_values,nu_mu_to_nu_e, lw = 2, color = 'blue')
semilogx()
savefig("nu_mu_nue_single_energy.pdf")

# %% [markdown]
# #Advanced example#

# %% [markdown]
# So far we have been able to calculate the oscillation probability in a given `Body` and `Track`. We have also been able to change the oscillation parameters (mixing angles and square mass differences), as well as changing the neutrino energy. This is what solving the **Schödinger evolution equation** does and it is a good approximation for most cases, but $\nu$-SQuIDS does **more**: it can solve a **quantum Boltzmann equation**. This means that it can solve a system of the following form

# %% [markdown]
# $$\frac{\partial\hat{\rho}_i}{\partial x} = i [H,\hat{\rho}_i] + \{A,\hat{\rho}_i\} + O(\hat{\rho}_i,\hat{\rho}_j)$$

# %% [markdown]
# where $\hat{\rho_i}$ represents the neutrino state at $E_\nu = E_i$, $H$ is the Hamiltonian, $A$ is a non unitary operator, and $O$ is an operator that contains the interactions between neutrino states of energies $E_i$ and $E_j$. The **SQuIDS package was designed to solve this kind of equations** (and *more*), in particular **$\nu$-SQuIDS implements this equation for neutrino propagation** in matter including the effects of neutral and charge current interactions, as well as the associated neutral and tau regeneration. For further details refer to [Gonzalez-Garcia et al.](#CHM)

# %% [markdown]
# To begin we have to specify the $\{E_i\}$ grid where the equation will be solve. $\nu$-SQuIDS provides two options for this:
# - Linear
# - Log
#
# for given $E_{\rm min}$, $E_{\rm max}$, and number of nodes. In this example we will construct a linear grid as between $1 {\rm GeV}$ and $10 {\rm GeV}$.

# %% [markdown]
# ##Multiple Energy Mode without Interactions##

# %%
nuSQ = nsq.nuSQUIDS(1.0,10.0,81,3,"neutrino",False,False)

# %% [markdown]
# We can see the nodes energies $\{E_i\}$, which is (in [eV])

# %%
np.array(nuSQ.GetERange())
# Out:
# array([  1.00000000e+09,   1.11250000e+09,   1.22500000e+09,
#          1.33750000e+09,   1.45000000e+09,   1.56250000e+09,
#          1.67500000e+09,   1.78750000e+09,   1.90000000e+09,
#          2.01250000e+09,   2.12500000e+09,   2.23750000e+09,
#          2.35000000e+09,   2.46250000e+09,   2.57500000e+09,
#          2.68750000e+09,   2.80000000e+09,   2.91250000e+09,
#          3.02500000e+09,   3.13750000e+09,   3.25000000e+09,
#          3.36250000e+09,   3.47500000e+09,   3.58750000e+09,
#          3.70000000e+09,   3.81250000e+09,   3.92500000e+09,
#          4.03750000e+09,   4.15000000e+09,   4.26250000e+09,
#          4.37500000e+09,   4.48750000e+09,   4.60000000e+09,
#          4.71250000e+09,   4.82500000e+09,   4.93750000e+09,
#          5.05000000e+09,   5.16250000e+09,   5.27500000e+09,
#          5.38750000e+09,   5.50000000e+09,   5.61250000e+09,
#          5.72500000e+09,   5.83750000e+09,   5.95000000e+09,
#          6.06250000e+09,   6.17500000e+09,   6.28750000e+09,
#          6.40000000e+09,   6.51250000e+09,   6.62500000e+09,
#          6.73750000e+09,   6.85000000e+09,   6.96250000e+09,
#          7.07500000e+09,   7.18750000e+09,   7.30000000e+09,
#          7.41250000e+09,   7.52500000e+09,   7.63750000e+09,
#          7.75000000e+09,   7.86250000e+09,   7.97500000e+09,
#          8.08750000e+09,   8.20000000e+09,   8.31250000e+09,
#          8.42500000e+09,   8.53750000e+09,   8.65000000e+09,
#          8.76250000e+09,   8.87500000e+09,   8.98750000e+09,
#          9.10000000e+09,   9.21250000e+09,   9.32500000e+09,
#          9.43750000e+09,   9.55000000e+09,   9.66250000e+09,
#          9.77500000e+09,   9.88750000e+09,   1.00000000e+10])

# %% [markdown]
# Lets propage this neutrino through the Earth in an atmospheric neutrino telescope setting. We can do that by setting the following `Body` and `Track`:

# %%
nuSQ.Set_Body(nsq.EarthAtm())
nuSQ.Set_Track(nsq.EarthAtm.Track(np.arccos(-1)))

# %% [markdown]
# Lets assume that $\phi_\nu = N_0 E^{-2}$, with flavor composition $\phi_e:\phi_\mu:\phi_\tau$ = $0:1:0$. $\nu$-SQuIDS input flux is a `numpy.ndarray` formatted in the following way :
#
# $$InputState \doteq [[\phi^1_e,\phi^1_\mu,\phi^1_\tau],...,[\phi^i_e,\phi^i_\mu,\phi^i_\tau],...,[\phi^n_e,\phi^n_\mu,\phi^n_\tau]]$$ where i = 1 to n and n is the number of energy nodes. We can implement this in the following way

# %%
N0 = 1.0e18
Eflux = lambda E: N0*E**-2
Einitial = (Eflux(np.array(nuSQ.GetERange())).reshape((81,1)))*(np.array([0.,1.,0.]).reshape(1,3))

# %% [markdown]
# We can plot the initial flux:

# %%
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$\phi_{ini}$")
plot(np.array(nuSQ.GetERange())/nuSQ.units.GeV,np.array(Einitial)[:,1])
loglog()
# Out:
# []

# %% [markdown]
# Lets set this initial state

# %%
nuSQ.Set_initial_state(Einitial,"flavor")

# %% [markdown]
# Lets **propage** this flux through the **Earth**

# %%
nuSQ.Set("rel_error", 1.0e-18);
nuSQ.Set("abs_error", 1.0e-18);
nuSQ.Set("h_max", 500.0*nuSQ.units.km);
nuSQ.Set("th12",0.563942);
nuSQ.Set("th13",0.154085);
nuSQ.Set("th23",0.785398);
nuSQ.Set("dm21sq",7.65e-05);
nuSQ.Set("dm31sq",0.00247);
nuSQ.Set("delta1",0.0);

# %%
t = nuSQ.GetTrack()
for x in np.arange(t.GetInitialX(),t.GetFinalX(), 10.0*nuSQ.units.km):
    t.SetX(x)
    nuSQ.Set_Track(t)
    print(nuSQ.GetBody().ye(nuSQ.GetTrack()))
# Out:
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.465600000001
# 0.4656
# 0.465599999999
# 0.465599999998
# 0.465599999999
# 0.465600000003
# 0.465600000008
# 0.465600000007
# 0.465599999993
# 0.465599999973
# 0.465599999971
# 0.465600000011
# 0.465600000088
# 0.465600000116
# 0.465600000002
# 0.465599999723
# 0.465599999556
# 0.465599999856
# 0.465600000833
# 0.465600001635
# 0.465600000938
# 0.465599997664
# 0.465599994178
# 0.465599995368
# 0.465600005864
# 0.465600020083
# 0.465600020274
# 0.465599988197
# 0.465599932996
# 0.465599917365
# 0.465600010191
# 0.465600215328
# 0.465600320483
# 0.46560006852
# 0.465599338859
# 0.465598804701
# 0.465599425313
# 0.465601910629
# 0.465604309777
# 0.465603063626
# 0.46559495557
# 0.465584947885
# 0.465586065213
# 0.465611328325
# 0.465650894384
# 0.465658194682
# 0.465583441622
# 0.465433911666
# 0.465370265175
# 0.465578669235
# 0.466119803658
# 0.466469279774
# 0.465932332033
# 0.464058055149
# 0.462425236021
# 0.463619599268
# 0.470019036086
# 0.480485121301
# 0.491011534409
# 0.497575598968
# 0.498892738715
# 0.497306203382
# 0.495404105726
# 0.494830458084
# 0.495163730457
# 0.495709139278
# 0.495928395799
# 0.495870109841
# 0.495720448489
# 0.495642592358
# 0.495648183331
# 0.495687511624
# 0.495713595583
# 0.495715244067
# 0.495705373235
# 0.495697065281
# 0.495695657209
# 0.495698000089
# 0.495700528986
# 0.495701198235
# 0.495700684406
# 0.495699946977
# 0.495699680574
# 0.495699778875
# 0.495699984744
# 0.495700081788
# 0.49570006837
# 0.49570001335
# 0.495699980123
# 0.49569997962
# 0.49569999369
# 0.495700004476
# 0.495700005878
# 0.495700002459
# 0.495699999119
# 0.495699998357
# 0.495699999134
# 0.495700000125
# 0.495700000444
# 0.495700000286
# 0.495700000004
# 0.495699999884
# 0.49569999991
# 0.495699999987
# 0.495700000029
# 0.495700000027
# 0.495700000007
# 0.495699999993
# 0.495699999992
# 0.495699999997
# 0.495700000001
# 0.495700000002
# 0.495700000001
# 0.4957
# 0.495699999999
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.4957
# 0.495699999999
# 0.4957
# 0.495700000001
# 0.495700000002
# 0.495700000002
# 0.495699999998
# 0.495699999993
# 0.495699999992
# 0.495700000003
# 0.495700000024
# 0.495700000031
# 0.4957
# 0.495699999925
# 0.495699999881
# 0.495699999964
# 0.495700000228
# 0.495700000439
# 0.495700000244
# 0.495699999357
# 0.495699998432
# 0.49569999878
# 0.495700001632
# 0.495700005422
# 0.495700005379
# 0.495699996628
# 0.495699981859
# 0.49569997797
# 0.495700003416
# 0.49570005849
# 0.49570008574
# 0.495700016266
# 0.495699819672
# 0.495699679286
# 0.495699852178
# 0.495700524119
# 0.495701159407
# 0.495700803545
# 0.49569860361
# 0.495695940315
# 0.495696311681
# 0.495703192975
# 0.495713763728
# 0.495715488403
# 0.495695036028
# 0.49565494627
# 0.495638617167
# 0.49569593204
# 0.495841530255
# 0.495932984659
# 0.495784130001
# 0.495278074251
# 0.494846792078
# 0.495183472915
# 0.496868636931
# 0.498724750518
# 0.498195783629
# 0.49276413403
# 0.482716458545
# 0.471911105617
# 0.464425915428
# 0.462354958944
# 0.463629779439
# 0.46565743054
# 0.466455037255
# 0.466227263109
# 0.465668893126
# 0.465384224597
# 0.465408354344
# 0.465555600974
# 0.465651393118
# 0.46565653197
# 0.465619428398
# 0.465588799906
# 0.465583853631
# 0.465592705609
# 0.465602061791
# 0.465604466778
# 0.465602510172
# 0.465599772457
# 0.465598805733
# 0.465599185709
# 0.465599952736
# 0.465600306889
# 0.465600252586
# 0.465600046875
# 0.46559992505
# 0.465599924499
# 0.465599977298
# 0.465600017005
# 0.465600021834
# 0.465600008944
# 0.465599996602
# 0.465599993883
# 0.46559999683
# 0.465600000502
# 0.465600001658
# 0.46560000105
# 0.465600000003
# 0.465599999567
# 0.465599999669
# 0.465599999954
# 0.465600000108
# 0.4656000001
# 0.465600000026
# 0.465599999975
# 0.465599999971
# 0.465599999989
# 0.465600000005
# 0.465600000008
# 0.465600000004
# 0.465599999999
# 0.465599999998
# 0.465599999999
# 0.4656
# 0.465600000001
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656
# 0.4656

# %%
nuSQ.GetTrack().GetX()/nuSQ.units.km
# Out:
# 12742.0

# %%
nuSQ.EvolveState()

# %% [markdown]
# That' it. Now `nuSQ` contains the evolved object. Lets get the information from it.

# %% [markdown]
# We can now calculate all of the flavor contributions at this current time. Notice that we can even increase the energy resolution in this multiple energy mode. The reason for this is that $\nu$-SQuIDS stores the neutrino states (${\rho_i}$) in the interaction basis, thus it can interpolate between states and then proyect into flavor. In symbols, for a given neutrino energy $E_\nu$ and flavor $\alpha$,
#
# $$\texttt{EvalFlavor}(E_\nu,\alpha) = {\rm Tr}\left[\Pi_\alpha (E_\nu) * \rho(E_\nu)\right]$$
#
# where $\Pi_\alpha (E_\nu) = e^{-i\hat{H_0}}\Pi_\alpha e^{i\hat{H_0}}$, with $H_0$ the base hamiltonian evaluated at $E_\nu$, and $\rho(E_\nu)$ is a linear interpolation of the $\rho_i$ states in the energy (node) axis.

# %%
e_range = np.linspace(1.0,10.0,300)

nu_e = np.array([nuSQ.EvalFlavor(0,EE*nuSQ.units.GeV,0) 
                           for EE in np.linspace(1.0,10.0,300)])
nu_mu = np.array([nuSQ.EvalFlavor(1,EE*nuSQ.units.GeV,0) 
                           for EE in np.linspace(1.0,10.0,300)])
nu_tau = np.array([nuSQ.EvalFlavor(2,EE*nuSQ.units.GeV,0) 
                           for EE in np.linspace(1.0,10.0,300)])

total = nu_e + nu_mu + nu_tau

# %%
figure(figsize = (8,6))

xlabel(r"$E_\nu [GeV]$")
ylabel(r"$\phi_e$")

plot(e_range,nu_e, lw = 2, color = 'red', label = r"$\nu_e$")
plot(e_range,nu_mu, lw = 2, color = 'blue', label = r"$\nu_\mu$")
plot(e_range,nu_tau, lw = 2, color = 'green', label = r"$\nu_\tau$")
plot(e_range,total, lw = 2, color = 'black', label = r"Total")
legend(fancybox = True, fontsize = 10)
loglog()
# Out:
# []

# %% [markdown]
# We can now try to reproduce the plot that we did in the single energy case: $P(\nu_\mu \to \nu_e)$. If you compare with the single energy plot you will notice that they are in agrement and, furthermore, the multiple energy mode **was able to reproduce the *fast* oscillation behaviour** at low energies eventhough it has **less energy nodes**

# %%
figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$P(\nu_\mu \to \nu_e)$")
nu_mu_to_nu_e = nu_e/Eflux(np.linspace(1.0,10.0,300)*nuSQ.units.GeV)
ylim(0,0.6)
plot(e_range,nu_mu_to_nu_e, lw = 2, color = 'blue')

# %%
figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"Oscillation Probability")
nu_mu_to_nu_mu = nu_mu/Eflux(np.linspace(1.0,10.0,300)*nuSQ.units.GeV)
nu_mu_to_nu_tau = nu_tau/Eflux(np.linspace(1.0,10.0,300)*nuSQ.units.GeV)
nu_mu_to_nu_e = nu_e/Eflux(np.linspace(1.0,10.0,300)*nuSQ.units.GeV)
plot(e_range,nu_mu_to_nu_mu, lw = 2, color = 'blue',label = r"$\nu_\mu$")
plot(e_range,nu_mu_to_nu_e, lw = 2, color = 'green',label = r"$\nu_e$")
plot(e_range,nu_mu_to_nu_tau, lw = 2, color = 'red',label = r"$\nu_\tau$")
legend(fancybox = True, fontsize = 15, loc = 'upper right')

# %% [markdown]
# ##Multiple Energy Mode with Interactions##

# %% [markdown]
# The multiple energy mode solves the quantum differential equactions in an energy grid (${E_i}$), this enables to include interactions between nodes at positions $i$ and $j$. We will now exemplify this.

# %%
nuSQ = nsq.nuSQUIDS(1.0e2,1.0e8,200,3,"neutrino",True,True)

# %%
N0 = 1.0e18; Power = -1.0
Eflux = lambda E: N0*E**Power
InitialFlux = (Eflux(np.array(nuSQ.GetERange())).reshape(200,1))*(np.array([0.,1.,0.]).reshape(1,3))

# %%
nuSQ.Set("rel_error", 1.0e-6)
nuSQ.Set("abs_error", 1.0e-6)
nuSQ.Set("h_max", 500.0*nuSQ.units.km)
#nuSQ.Set("h_min", 1.0*nuSQ.units.meter)

# %%
nuSQ.Set_initial_state(InitialFlux,"flavor")
nuSQ.Set_Body(nsq.EarthAtm())
nuSQ.Set_Track(nsq.EarthAtm.Track(np.arccos(-1.0)))

# %%
# %time nuSQ.EvolveState()
# Out:
# CPU times: user 51.7 s, sys: 37.3 ms, total: 51.7 s
# Wall time: 51.7 s

# %%
nu_e = np.array([nuSQ.EvalFlavorAtNode(0,ie,0) 
                           for ie in range(200)])
nu_mu = np.array([nuSQ.EvalFlavorAtNode(1,ie,0) 
                           for ie in range(200)])
nu_tau = np.array([nuSQ.EvalFlavorAtNode(2,ie,0) 
                           for ie in range(200)])

E_range = np.array(nuSQ.GetERange())/nuSQ.units.GeV

total = nu_e + nu_mu + nu_tau

# %%
figure(figsize = (8,6))

xlabel(r"$E_\nu [GeV]$")
ylabel(r"$\phi_\nu$")

plot(E_range,nu_e, lw = 2, color = 'red', label = r"$\nu_e$")
plot(E_range,nu_mu, lw = 2, color = 'blue', label = r"$\nu_\mu$")
plot(E_range,nu_tau, lw = 2, color = 'green', label = r"$\nu_\tau$")
plot(E_range,total, lw = 2, color = 'black', label = r"Total")
legend(fancybox = True, loc = 'lower left', fontsize = 15)
loglog()
# Out:
# []

# %% [markdown]
# We can compare this calculation with Figure 4 of [Gonzalez-Garcia et al.](#CHM) and find them in excellent agreement. Just note that the small kink at $10^2$ is the result of neutrino oscillations and the difference at high energy attenuation amplitud is due to different cross section.

# %%
figure(figsize = (8,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"$(d\phi^{\rm final}/dE)/(d\phi^{\rm final}/dE)$")
nu_mu_to_nu_mu = nu_mu/Eflux(E_range*nuSQ.units.GeV)
plot(E_range,nu_mu_to_nu_mu, lw = 2, color = 'blue')
title(r"Muon Neutrino", fontsize = 25)
text(5.0e4,3.0,r"$d\phi/dE \sim E^{-1}$", fontsize = 25)
axhline (1.0, color = "k", lw = 3)
ylim(1.0e-3,1.0e1)
xlim(1.0e2,2.0e6)
loglog()
# Out:
# []

# %% [markdown]
# ###Handeling neutrinos and antineutrinos with tau regeneration###

# %% [markdown]
# To include $\tau$ regeneration we have to work on the multi energy mode and set the neutrino type to "both". We can initialize the $\nu$-SQuIDS object in the following way

# %%
nuSQ = nsq.nuSQUIDS(1.0e2,1.0e8,200,3,"both",True,True)

# %% [markdown]
# In this case we need to specify the neutrino and antineutrino initial fluxes. Those have the following format:
#
# $$InputState \doteq [[[\phi^1_e,\phi^1_\mu,\phi^1_\tau],[\bar{\phi}^1_e,\bar{\phi}^1_\mu,\bar{\phi}^1_\tau]],...,[[\phi^i_e,\phi^i_\mu,\phi^i_\tau],[\bar{\phi}^i_e,\bar{\phi}^i_\mu,\bar{\phi}^i_\tau]],...,[[\phi^n_e,\phi^n_\mu,\phi^n_\tau],[\bar{\phi}^n_e,\bar{\phi}^n_\mu,\bar{\phi}^n_\tau]]]$$ where i = 1 to n and n is the number of energy nodes and $\phi$ ($\bar{\phi}$) is the neutrino (antineutrino) flux.

# %%
N0 = 1.0e18; Power = -1.0
Eflux = lambda E: N0*E**Power

InitialFlux = zeros((200,2,3))
for i,E in enumerate(nuSQ.GetERange()):
    InitialFlux[i][0][0] = 0.0
    InitialFlux[i][1][0] = 0.0
    InitialFlux[i][0][1] = Eflux(E)
    InitialFlux[i][1][1] = Eflux(E)
    InitialFlux[i][0][2] = 0.0
    InitialFlux[i][1][2] = 0.0

# %%
nuSQ.Set_initial_state(InitialFlux,"flavor")
nuSQ.Set_Body(nsq.EarthAtm())
nuSQ.Set_Track(nsq.EarthAtm.Track(np.arccos(-1.0)))
nuSQ.Set("rel_error", 1.0e-6);
nuSQ.Set("abs_error", 1.0e-6);
nuSQ.Set("h_max", 500.0*nuSQ.units.km )
nuSQ.Set_nuSQUIDS("taureg",True)

# %%
# %time nuSQ.EvolveState()
# Out:
# CPU times: user 1min 45s, sys: 140 ms, total: 1min 45s
# Wall time: 1min 45s

# %%
nu_mu = np.array([nuSQ.EvalFlavorAtNode(1,ie,0) 
                           for ie in range(200)])
nu_mu_bar = np.array([nuSQ.EvalFlavorAtNode(1,ie,1) 
                           for ie in range(200)])

E_range = np.array(nuSQ.GetERange())/nuSQ.units.GeV

# %%
figure(figsize = (6,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"${\rm E} \times \phi_\nu (E_\nu)$")
E_times_nu_mu = np.array([ nu_mu[i] for i,EE in enumerate(E_range*nuSQ.units.GeV)])
E_times_nu_mu_bar = np.array([ nu_mu_bar[i] for i,EE in enumerate(E_range*nuSQ.units.GeV)])
plot(E_range,E_times_nu_mu, lw = 3, color = 'blue')
plot(E_range,E_times_nu_mu_bar, lw = 3, color = 'blue')
#axhline (0.5e-13, color = "k", lw = 3)
#ylim(1.0e-15,1.0e-12)
#loglog()

# %% [markdown]
# ##Neutrino Oscillation in a (3+1) model##

# %%
nuSQ = nsq.nuSQUIDS(1.0,100.0,201,4,"antineutrino",False,False)

# %%
nuSQ.Set_Body(nsq.EarthAtm())
nuSQ.Set_Track(nsq.EarthAtm.Track(np.arccos(-1)))

# %%
N0 = 1.0e18
Eflux = lambda E: N0*E**-2
Einitial = (Eflux(np.array(nuSQ.GetERange())).reshape(201,1))*(np.array([0.,1.,0.,0.]).reshape(1,4))

# %%
nuSQ.Set_initial_state(Einitial,"flavor")

# %%
nuSQ.Set("rel_error", 1.0e-10);
nuSQ.Set("abs_error", 1.0e-10);
#nuSQ.Set("h_max", 50.0*nuSQ.units.km);
nuSQ.Set("th12",0.563942);
nuSQ.Set("th13",0.154085);
nuSQ.Set("th23",0.785398);
nuSQ.Set("dm21sq",7.65e-05);
nuSQ.Set("dm31sq",0.00247);
nuSQ.Set("dm41sq", 3.0);
nuSQ.Set("th24", 0.7);
nuSQ.Set("delta1",0.0);

# %%
nuSQ.EvolveState()

# %%
e_range = np.logspace(0,2,400)

nu_e = np.array([nuSQ.EvalFlavor(0,EE*nuSQ.units.GeV,0) 
                           for EE in e_range])
nu_mu = np.array([nuSQ.EvalFlavor(1,EE*nuSQ.units.GeV,0) 
                           for EE in e_range])
nu_tau = np.array([nuSQ.EvalFlavor(2,EE*nuSQ.units.GeV,0) 
                           for EE in e_range])

total = nu_e + nu_mu + nu_tau

# %%
figure(figsize = (8,6))

xlabel(r"$E_\nu [GeV]$")
ylabel(r"$\phi_\nu$")

plot(e_range,nu_e, lw = 2, color = 'red', label = r"$\nu_e$")
plot(e_range,nu_mu, lw = 2, color = 'blue', label = r"$\nu_\mu$")
plot(e_range,nu_tau, lw = 2, color = 'green', label = r"$\nu_\tau$")
plot(e_range,total, lw = 2, color = 'black', label = r"Total")
legend(fancybox = True, fontsize = 14)
semilogx()
loglog()

savefig("sterile_osc_demo_antineutrino.pdf")

# %% [markdown]
# #Python Toolbox#

# %% [markdown]
# We have included a set of python functions to extend the C++ $\nu$-SQuIDS class. We demostrate some of these functions, which assume to be run under the ipython environment, further information can be found in the documentation.

# %%
import nuSQUIDSTools

# %%
nuSQ = nsq.nuSQUIDS("/Users/carguelles/Workspace/SQuIDS/nuSQuIDS/out_muon.hdf5")

# %%
nu_mu = np.array([ nuSQ.EvalFlavorAtNode(1,ie,0) for ie,EE in enumerate(nuSQ.GetERange())])
nu_mu_bar = np.array([ nuSQ.EvalFlavorAtNode(1,ie,1) for ie,EE in enumerate(nuSQ.GetERange())])

# %%
figure(figsize = (6,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"${\rm E} \times \phi_\nu (E_\nu)$")
e_range = np.array(nuSQ.GetERange())/nuSQ.units.GeV
plot(e_range,(nu_mu+nu_mu_bar)*(e_range*nuSQ.units.GeV)*(0.25*10**-13*10**-18), lw = 3)
axhline (0.5e-13, color = "k", lw = 3)
ylim(1.0e-15,1.0e-12)
xlim(1.0e2,1.0e6)
grid()
loglog()
# Out:
# []

# %%
nuSQ = nsq.nuSQUIDS("/Users/carguelles/Workspace/SQuIDS/nuSQuIDS/out_tau.hdf5")

# %%
nuSQ.EvalFlavorAtNode(2,0,1)
# Out:
# 8664002.665584777

# %%
plot([ nuSQ.EvalFlavorAtNode(2,ei,1) for ei in range(nuSQ.GetNumE())])
semilogy()
# Out:
# []

# %%
nu_tau = np.array([ nuSQ.EvalFlavorAtNode(2,ie,0) for ie,EE in enumerate(nuSQ.GetERange())])
nu_tau_bar = np.array([ nuSQ.EvalFlavorAtNode(2,ie,1) for ie,EE in enumerate(nuSQ.GetERange())])

# %%
figure(figsize = (6,6))
xlabel(r"$E_\nu [GeV]$")
ylabel(r"${\rm E} \times \phi_\nu (E_\nu)$")
e_range = np.array(nuSQ.GetERange())/nuSQ.units.GeV
plot(e_range,(nu_tau+nu_tau_bar)*(e_range*nuSQ.units.GeV)*(0.25*10**-13*10**-18), lw = 3)
axhline (0.5e-13, color = "k", lw = 3)
ylim(1.0e-15,1.0e-12)
xlim(1.0e2,1.0e6)
grid()
loglog()
# Out:
# []

# %%
nuSQ.PrintStatus("/Users/carguelles/Workspace/SQuIDS/nuSQuIDS/link/python/example/tex/test.tex")

# %%
nuSQ.Set("th12",0.563942);
nuSQ.Set("th13",0.154085);
nuSQ.Set("th23",0.785398);
nuSQ.Set("dm21sq",7.65e-05);
nuSQ.Set("dm31sq",0.00247);
nuSQ.Set("delta1",0.0);

# %% [markdown]
# #References#
#
# - <a id="CHM">[1]</a> *M.C. Gonzalez-Garcia, F. Halzen, and M. Maltoni*, **Physics Reach of High-Energy and High-Statistics IceCube Atmospheric Neutrino Data**, Phys.Rev. D71 (2005) 093010. http://arxiv.org/abs/hep-ph/0502223
# - *C.A. Argüelles-Delgado and J. Salvado*, **SQuIDS: A Simple Quantum Integro Differential equation Solve.** On preparation.
# - *C.A. Argüelles-Delgado and J. Salvado*, **$\nu$-SQuIDS: A tool box for neutrino oscillation experiments.** On preparation.
# - M. Galassi et al, GNU Scientific Library Reference Manual (3rd Ed.), ISBN 0954612078. http://www.gnu.org/software/gsl/

# %%
import nuSQUIDSpy as nsq
import numpy as np
rc('font', family='serif', size=20)

# %%
nuSQ = nsq.nuSQUIDS("/Users/carguelles/Workspace/SQuIDS/nuSQuIDS/out_example1_muon.hdf5")

# %%
e_range = np.array(nuSQ.GetERange())/nuSQ.units.GeV

# %%
nu_e = np.array([ nuSQ.EvalFlavorAtNode(0,ie,0) for ie in range(nuSQ.GetNumE())])
nu_mu = np.array([ nuSQ.EvalFlavorAtNode(1,ie,0) for ie in range(nuSQ.GetNumE())])
nu_tau = np.array([ nuSQ.EvalFlavorAtNode(2,ie,0) for ie in range(nuSQ.GetNumE())])

# %%
plot(e_range,nu_e)
semilogx()
# Out:
# []
